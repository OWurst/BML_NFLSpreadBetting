# %%
import pandas as pd

# %%
australia_historical_game_outcomes_df = pd.read_excel('Australia_Historical_Game_Outcomes.xlsx', engine='openpyxl')

# %%
australia_historical_game_outcomes_df.head(5)
# Out:
#                   Date           Home Team             Away Team  Home Score  \
# 0  2024-12-02 00:00:00      Denver Broncos      Cleveland Browns          41
# 1  2024-12-01 00:00:00       Buffalo Bills   San Francisco 49ers          35
# 2  2024-12-01 00:00:00    Baltimore Ravens   Philadelphia Eagles          19
# 3  2024-12-01 00:00:00   Carolina Panthers  Tampa Bay Buccaneers          23
# 4  2024-12-01 00:00:00  New Orleans Saints      Los Angeles Rams          14
#
#    Away Score Overtime? Playoff Game? Neutral Venue?  Home Odds Open  \
# 0          32       NaN           NaN            NaN           1.312
# 1          10       NaN           NaN            NaN           1.588
# 2          24       NaN           NaN            NaN           1.645
# 3          26         Y           NaN            NaN           3.350
# 4          21       NaN           NaN            NaN           2.150
#
#    Home Odds Min  ...  Total Score Close  Total Score Over Open  \
# 0           1.28  ...               41.5                  1.909
# 1           1.28  ...               45.5                  1.909
# 2           1.59  ...               50.0                  1.909
# 3           3.00  ...               46.0                  1.909
# 4           2.10  ...               49.0                  1.909
#
#    Total Score Over Min  Total Score Over Max  Total Score Over Close  \
# 0                 1.909                 1.909                   1.909
# 1                 1.909                 1.909                   1.909
# 2                 1.870                 1.909                   1.909
# 3                 1.909                 1.909                   1.870
# 4                 1.909                 1.909                   1.870
#
#    Total Score Under Open  Total Score Under Min  Total Score Under Max  \
# 0                   1.909                  1.909                  1.909
# 1                   1.909                  1.909                  1.909
# 2                   1.909                  1.870                  1.909
# 3                   1.909                  1.909                  1.909
# 4                   1.909                  1.909                  1.909
#
#    Total Score Under Close  Notes
# 0                    1.909    NaN
# 1                    1.909    NaN
# 2                    1.909    NaN
# 3                    1.870    NaN
# 4                    1.870    NaN
#
# [5 rows x 45 columns]

# %%
australia_historical_game_outcomes_df.columns
# Out:
# Index(['Date', 'Home Team', 'Away Team', 'Home Score', 'Away Score',
#        'Overtime?', 'Playoff Game?', 'Neutral Venue?', 'Home Odds Open',
#        'Home Odds Min', 'Home Odds Max', 'Home Odds Close', 'Away Odds Open',
#        'Away Odds Min', 'Away Odds Max', 'Away Odds Close', 'Home Line Open',
#        'Home Line Min', 'Home Line Max', 'Home Line Close', 'Away Line Open',
#        'Away Line Min', 'Away Line Max', 'Away Line Close',
#        'Home Line Odds Open', 'Home Line Odds Min', 'Home Line Odds Max',
#        'Home Line Odds Close', 'Away Line Odds Open', 'Away Line Odds Min',
#        'Away Line Odds Max', 'Away Line Odds Close', 'Total Score Open',
#        'Total Score Min', 'Total Score Max', 'Total Score Close',
#        'Total Score Over Open', 'Total Score Over Min', 'Total Score Over Max',
#        'Total Score Over Close', 'Total Score Under Open',
#        'Total Score Under Min', 'Total Score Under Max',
#        'Total Score Under Close', 'Notes'],
#       dtype='object')

# %%
australia_historical_game_outcomes_df = australia_historical_game_outcomes_df[['Date','Home Team', 'Away Team', 'Home Score', 'Away Score', 'Home Line Close']]

# %%
australia_historical_game_outcomes_df['Score Diff'] = australia_historical_game_outcomes_df['Home Score'] - australia_historical_game_outcomes_df['Away Score']

# %%
australia_historical_game_outcomes_df.head(5)
# Out:
#                   Date           Home Team             Away Team  Home Score  \
# 0  2024-12-02 00:00:00      Denver Broncos      Cleveland Browns          41
# 1  2024-12-01 00:00:00       Buffalo Bills   San Francisco 49ers          35
# 2  2024-12-01 00:00:00    Baltimore Ravens   Philadelphia Eagles          19
# 3  2024-12-01 00:00:00   Carolina Panthers  Tampa Bay Buccaneers          23
# 4  2024-12-01 00:00:00  New Orleans Saints      Los Angeles Rams          14
#
#    Away Score  Home Line Close  Score Diff
# 0          32             -6.5           9
# 1          10             -6.5          25
# 2          24             -3.0          -5
# 3          26              6.5          -3
# 4          21              2.5          -7

# %%
australia_historical_game_outcomes_df['Home Spread Diff'] = australia_historical_game_outcomes_df['Home Line Close'] + australia_historical_game_outcomes_df['Score Diff']

# %%
australia_historical_game_outcomes_df.head(25)
# Out:
#                    Date              Home Team             Away Team  \
# 0   2024-12-02 00:00:00         Denver Broncos      Cleveland Browns
# 1   2024-12-01 00:00:00          Buffalo Bills   San Francisco 49ers
# 2   2024-12-01 00:00:00       Baltimore Ravens   Philadelphia Eagles
# 3   2024-12-01 00:00:00      Carolina Panthers  Tampa Bay Buccaneers
# 4   2024-12-01 00:00:00     New Orleans Saints      Los Angeles Rams
# 5   2024-12-01 00:00:00        Atlanta Falcons  Los Angeles Chargers
# 6   2024-12-01 00:00:00     Cincinnati Bengals   Pittsburgh Steelers
# 7   2024-12-01 00:00:00   Jacksonville Jaguars        Houston Texans
# 8   2024-12-01 00:00:00      Minnesota Vikings     Arizona Cardinals
# 9   2024-12-01 00:00:00   New England Patriots    Indianapolis Colts
# 10  2024-12-01 00:00:00          New York Jets      Seattle Seahawks
# 11  2024-12-01 00:00:00  Washington Commanders      Tennessee Titans
# 12  2024-11-29 00:00:00     Kansas City Chiefs     Las Vegas Raiders
# 13  2024-11-28 00:00:00      Green Bay Packers        Miami Dolphins
# 14  2024-11-28 00:00:00         Dallas Cowboys       New York Giants
# 15  2024-11-28 00:00:00          Detroit Lions         Chicago Bears
# 16  2024-11-25 00:00:00   Los Angeles Chargers      Baltimore Ravens
# 17  2024-11-24 00:00:00       Los Angeles Rams   Philadelphia Eagles
# 18  2024-11-24 00:00:00      Green Bay Packers   San Francisco 49ers
# 19  2024-11-24 00:00:00       Seattle Seahawks     Arizona Cardinals
# 20  2024-11-24 00:00:00      Las Vegas Raiders        Denver Broncos
# 21  2024-11-24 00:00:00      Carolina Panthers    Kansas City Chiefs
# 22  2024-11-24 00:00:00          Chicago Bears     Minnesota Vikings
# 23  2024-11-24 00:00:00         Houston Texans      Tennessee Titans
# 24  2024-11-24 00:00:00     Indianapolis Colts         Detroit Lions
#
#     Home Score  Away Score  Home Line Close  Score Diff  Home Spread Diff  \
# 0           41          32             -6.5           9               2.5
# 1           35          10             -6.5          25              18.5
# 2           19          24             -3.0          -5              -8.0
# 3           23          26              6.5          -3               3.5
# 4           14          21              2.5          -7              -4.5
# 5           13          17              1.0          -4              -3.0
# 6           38          44             -3.0          -6              -9.0
# 7           20          23              3.0          -3               0.0
# 8           23          22             -3.5           1              -2.5
# 9           24          25              2.5          -1               1.5
# 10          21          26             -1.5          -5              -6.5
# 11          42          19             -6.0          23              17.0
# 12          19          17            -13.5           2             -11.5
# 13          30          17             -3.5          13               9.5
# 14          27          20             -4.0           7               3.0
# 15          23          20            -10.0           3              -7.0
# 16          23          30              3.0          -7              -4.0
# 17          20          37              3.0         -17             -14.0
# 18          38          10             -6.0          28              22.0
# 19          16           6              1.0          10              11.0
# 20          19          29              5.5         -10              -4.5
# 21          27          30             10.5          -3               7.5
# 22          27          30              3.0          -3               0.0
# 23          27          32             -8.0          -5             -13.0
# 24           6          24              7.0         -18             -11.0
#
#    Home vs Spread
# 0             Win
# 1             Win
# 2            Lose
# 3             Win
# 4            Lose
# 5            Lose
# 6            Lose
# 7            Push
# 8            Lose
# 9             Win
# 10           Lose
# 11            Win
# 12           Lose
# 13            Win
# 14            Win
# 15           Lose
# 16           Lose
# 17           Lose
# 18            Win
# 19            Win
# 20           Lose
# 21            Win
# 22           Push
# 23           Lose
# 24           Lose

# %%
# home beat spread if home spread diff is greater than 0
# home push spread if home spread diff is equal to 0
# home lose spread if home spread diff is less than 0
australia_historical_game_outcomes_df['Home vs Spread'] = australia_historical_game_outcomes_df['Home Spread Diff'].apply(lambda x: 'Win' if x > 0 else ('Push' if x == 0 else 'Lose'))

# %%
# get the number of games that home team beat the spread
australia_historical_game_outcomes_df['Home vs Spread'].value_counts()
# Out:
# Home vs Spread
# Lose    3593
# Win     1374
# Push      89
# Name: count, dtype: int64
